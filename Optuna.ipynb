# %%
import pandas as pd
import numpy as np

import optuna

import sklearn.ensemble as ensemble
import sklearn.metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Hyperarameter Tuning for Classification With Optuna

# %%
df = pd.read_csv("train.csv", index_col=[0])
df.head()
# Its cleadned and scaled data
# Out:
#    CustomerID       Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0    0.591569  0.418605            0.0       1.0         0.063492    0.666667
# 1    0.854717  0.674419            0.0       1.0         0.126984    1.000000
# 2    0.739922  0.279070            0.0       1.0         0.380952    0.666667
# 3    0.294659  0.418605            1.0       0.0         0.158730    0.000000
# 4    0.826478  0.209302            0.0       0.0         0.253968    0.000000
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 0     1.0                    0.50              0.625            0.50
# 1     0.0                    0.75              1.000            0.75
# 2     1.0                    0.50              0.875            0.50
# 3     0.0                    0.50              0.375            0.50
# 4     0.0                    0.50              0.875            0.00
#
#    PreferredPropertyStar  MaritalStatus  NumberOfTrips  Passport  \
# 0                    0.0       0.333333       0.166667       0.0
# 1                    0.5       0.666667       0.666667       1.0
# 2                    0.0       1.000000       0.166667       0.0
# 3                    0.5       0.666667       0.000000       0.0
# 4                    0.5       0.666667       0.333333       0.0
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  Designation  \
# 0                    0.50     1.0                  0.333333         0.00
# 1                    1.00     1.0                  0.333333         0.75
# 2                    0.75     1.0                  0.333333         0.00
# 3                    0.50     1.0                  0.333333         0.00
# 4                    0.50     1.0                  0.666667         0.25
#
#    MonthlyIncome  ProdTaken
# 0       0.524538          0
# 1       1.000000          0
# 2       0.583706          0
# 3       0.356895          0
# 4       0.403891          0

# %%
X = df.drop("ProdTaken", axis=1)
y = df.ProdTaken

# %% [markdown]
# #### In optuna, A Trial represents a single call of the objective function
# #### Study shows an optimization session which contains a set of trials
# #### Study: optimization based on an objective function
# #### Trial: a single execution of the objective function

# %%
def objective(trial):
    #  hyperparameter setting
    # Here i have just taken parameters for RandomForestClassifier
    entropy = trial.suggest_categorical('criterion', ["gini", "entropy"])
    n_estimators = trial.suggest_int("n_estimators", 10, 1000)
    max_depth = trial.suggest_int("max_depth", 3, 20)
    max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)

    # data loading and train-test split
    df = pd.read_csv("train.csv", index_col=[0])
    X = df.drop("ProdTaken", axis=1)
    y = df.ProdTaken
    X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=0)
    
    # model training and evaluation
    model = ensemble.RandomForestClassifier(
        n_estimators = n_estimators,
        criterion= entropy,
        max_depth = max_depth,
        max_features = max_features
    )
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    
    # Just wanna to improve f1 score (You can replace this with according to your needs)
    error = sklearn.metrics.f1_score(y_val, y_pred)

    # output: evaluation score
    return error

# %% [markdown]
# ###  **Creating an study for that ML model and optimize it**

# %%
# In Optuna, we use the study object to manage optimization.
# Method :func:`~optuna.create_study` returns a study object.
# A study object has useful properties for analyzing the optimization outcome.
study = optuna.create_study(direction='maximize') #Set minimize for minimization and maximize for maximization.
#To start the optimization, we create a study object and pass the objective function to method
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-12-23 17:42:55,785] A new study created in memory with name: no-name-7e1fc8dd-f92a-4e2d-ad4c-e63a8b055b42
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:00,795] Trial 0 finished with value: 0.9282868525896415 and parameters: {'criterion': 'entropy', 'n_estimators': 296, 'max_depth': 16, 'max_features': 0.20896660372504566}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:23,092] Trial 1 finished with value: 0.9252243270189432 and parameters: {'criterion': 'gini', 'n_estimators': 971, 'max_depth': 15, 'max_features': 0.4598905844877823}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:31,829] Trial 2 finished with value: 0.8694779116465864 and parameters: {'criterion': 'gini', 'n_estimators': 396, 'max_depth': 8, 'max_features': 0.7882336068714614}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:35,959] Trial 3 finished with value: 0.9045226130653266 and parameters: {'criterion': 'entropy', 'n_estimators': 242, 'max_depth': 10, 'max_features': 0.3584185586994612}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:40,361] Trial 4 finished with value: 0.9218436873747496 and parameters: {'criterion': 'entropy', 'n_estimators': 302, 'max_depth': 20, 'max_features': 0.23746504142315888}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:45,060] Trial 5 finished with value: 0.9076620825147349 and parameters: {'criterion': 'gini', 'n_estimators': 700, 'max_depth': 11, 'max_features': 0.05888003063569512}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:43:52,313] Trial 6 finished with value: 0.7885939036381515 and parameters: {'criterion': 'gini', 'n_estimators': 734, 'max_depth': 4, 'max_features': 0.45441265507533996}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:01,022] Trial 7 finished with value: 0.7487969201154957 and parameters: {'criterion': 'gini', 'n_estimators': 778, 'max_depth': 3, 'max_features': 0.6695919844105446}. Best is trial 0 with value: 0.9282868525896415.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:04,305] Trial 8 finished with value: 0.9332003988035891 and parameters: {'criterion': 'gini', 'n_estimators': 216, 'max_depth': 19, 'max_features': 0.23461282371105693}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:13,122] Trial 9 finished with value: 0.8875502008032129 and parameters: {'criterion': 'gini', 'n_estimators': 424, 'max_depth': 9, 'max_features': 0.6380945810836556}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:13,608] Trial 10 finished with value: 0.911764705882353 and parameters: {'criterion': 'entropy', 'n_estimators': 38, 'max_depth': 19, 'max_features': 0.03100571908813532}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:15,144] Trial 11 finished with value: 0.9253731343283582 and parameters: {'criterion': 'entropy', 'n_estimators': 90, 'max_depth': 16, 'max_features': 0.24778013249459885}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:22,519] Trial 12 finished with value: 0.9255533199195172 and parameters: {'criterion': 'entropy', 'n_estimators': 247, 'max_depth': 16, 'max_features': 0.23890923781924414}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:49,424] Trial 13 finished with value: 0.9189189189189189 and parameters: {'criterion': 'entropy', 'n_estimators': 603, 'max_depth': 18, 'max_features': 0.9665239913878267}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:44:51,148] Trial 14 finished with value: 0.9195630585898709 and parameters: {'criterion': 'entropy', 'n_estimators': 145, 'max_depth': 14, 'max_features': 0.14827756995891456}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:03,680] Trial 15 finished with value: 0.9229229229229229 and parameters: {'criterion': 'gini', 'n_estimators': 514, 'max_depth': 13, 'max_features': 0.3417176768616621}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:10,982] Trial 16 finished with value: 0.9313432835820895 and parameters: {'criterion': 'gini', 'n_estimators': 360, 'max_depth': 18, 'max_features': 0.15037407301639832}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:13,810] Trial 17 finished with value: 0.9252243270189432 and parameters: {'criterion': 'gini', 'n_estimators': 166, 'max_depth': 18, 'max_features': 0.08410996869714897}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:22,990] Trial 18 finished with value: 0.9322709163346613 and parameters: {'criterion': 'gini', 'n_estimators': 403, 'max_depth': 20, 'max_features': 0.373050831862104}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:35,788] Trial 19 finished with value: 0.9221556886227545 and parameters: {'criterion': 'gini', 'n_estimators': 498, 'max_depth': 20, 'max_features': 0.5872937994184959}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:42,219] Trial 20 finished with value: 0.862475442043222 and parameters: {'criterion': 'gini', 'n_estimators': 574, 'max_depth': 7, 'max_features': 0.3071959646220105}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:49,479] Trial 21 finished with value: 0.9229229229229229 and parameters: {'criterion': 'gini', 'n_estimators': 385, 'max_depth': 18, 'max_features': 0.4027809689843873}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:54,038] Trial 22 finished with value: 0.9281437125748504 and parameters: {'criterion': 'gini', 'n_estimators': 378, 'max_depth': 20, 'max_features': 0.14013207139204495}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:45:58,264] Trial 23 finished with value: 0.9292123629112662 and parameters: {'criterion': 'gini', 'n_estimators': 191, 'max_depth': 17, 'max_features': 0.5232038654100467}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:02,554] Trial 24 finished with value: 0.9232283464566928 and parameters: {'criterion': 'gini', 'n_estimators': 315, 'max_depth': 13, 'max_features': 0.15743640560994265}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:13,522] Trial 25 finished with value: 0.9241516966067864 and parameters: {'criterion': 'gini', 'n_estimators': 467, 'max_depth': 19, 'max_features': 0.28348816392854004}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:14,470] Trial 26 finished with value: 0.919080919080919 and parameters: {'criterion': 'gini', 'n_estimators': 34, 'max_depth': 18, 'max_features': 0.3688323790146474}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:24,497] Trial 27 finished with value: 0.9273631840796022 and parameters: {'criterion': 'gini', 'n_estimators': 573, 'max_depth': 14, 'max_features': 0.17387793409653374}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:29,924] Trial 28 finished with value: 0.9213930348258706 and parameters: {'criterion': 'gini', 'n_estimators': 350, 'max_depth': 17, 'max_features': 0.08503049559042393}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:35,531] Trial 29 finished with value: 0.9198396793587174 and parameters: {'criterion': 'gini', 'n_estimators': 231, 'max_depth': 20, 'max_features': 0.5178654292072619}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:38,220] Trial 30 finished with value: 0.9267803410230693 and parameters: {'criterion': 'gini', 'n_estimators': 120, 'max_depth': 17, 'max_features': 0.4325828845998894}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:43,112] Trial 31 finished with value: 0.9232303090727817 and parameters: {'criterion': 'gini', 'n_estimators': 198, 'max_depth': 17, 'max_features': 0.5300010593923888}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:47,862] Trial 32 finished with value: 0.9275074478649455 and parameters: {'criterion': 'gini', 'n_estimators': 283, 'max_depth': 16, 'max_features': 0.3145440352511386}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:46:59,415] Trial 33 finished with value: 0.9243027888446215 and parameters: {'criterion': 'gini', 'n_estimators': 428, 'max_depth': 19, 'max_features': 0.7711058932516359}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:47:06,227] Trial 34 finished with value: 0.9232303090727817 and parameters: {'criterion': 'gini', 'n_estimators': 194, 'max_depth': 15, 'max_features': 0.4095987507777437}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:47:20,008] Trial 35 finished with value: 0.922 and parameters: {'criterion': 'gini', 'n_estimators': 324, 'max_depth': 19, 'max_features': 0.5723376958683385}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:47:38,229] Trial 36 finished with value: 0.9305555555555556 and parameters: {'criterion': 'gini', 'n_estimators': 986, 'max_depth': 17, 'max_features': 0.20493618717600998}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:47:48,047] Trial 37 finished with value: 0.9252243270189432 and parameters: {'criterion': 'gini', 'n_estimators': 861, 'max_depth': 15, 'max_features': 0.2081686753644129}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:47:56,622] Trial 38 finished with value: 0.8474903474903476 and parameters: {'criterion': 'gini', 'n_estimators': 983, 'max_depth': 6, 'max_features': 0.018550084723610416}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:48:04,347] Trial 39 finished with value: 0.9144542772861356 and parameters: {'criterion': 'gini', 'n_estimators': 900, 'max_depth': 12, 'max_features': 0.10113738983685759}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:48:15,216] Trial 40 finished with value: 0.9269269269269269 and parameters: {'criterion': 'entropy', 'n_estimators': 720, 'max_depth': 19, 'max_features': 0.21273280353446078}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:48:22,340] Trial 41 finished with value: 0.9259999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 266, 'max_depth': 17, 'max_features': 0.48980309518501797}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:48:33,122] Trial 42 finished with value: 0.9304174950298211 and parameters: {'criterion': 'gini', 'n_estimators': 653, 'max_depth': 20, 'max_features': 0.26820628466730945}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:48:44,444] Trial 43 finished with value: 0.9282868525896415 and parameters: {'criterion': 'gini', 'n_estimators': 665, 'max_depth': 20, 'max_features': 0.2710727157711246}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:48:58,211] Trial 44 finished with value: 0.9281437125748504 and parameters: {'criterion': 'gini', 'n_estimators': 827, 'max_depth': 20, 'max_features': 0.19503495640380092}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:49:10,012] Trial 45 finished with value: 0.9279999999999999 and parameters: {'criterion': 'gini', 'n_estimators': 443, 'max_depth': 18, 'max_features': 0.35044023695052007}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:49:34,473] Trial 46 finished with value: 0.9318637274549099 and parameters: {'criterion': 'entropy', 'n_estimators': 910, 'max_depth': 19, 'max_features': 0.24920415620713954}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:49:47,293] Trial 47 finished with value: 0.90748031496063 and parameters: {'criterion': 'entropy', 'n_estimators': 945, 'max_depth': 10, 'max_features': 0.12592797446598097}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:50:05,472] Trial 48 finished with value: 0.9269269269269269 and parameters: {'criterion': 'entropy', 'n_estimators': 931, 'max_depth': 16, 'max_features': 0.2347819070452258}. Best is trial 8 with value: 0.9332003988035891.
# C:\Users\KIRTIMAN\AppData\Local\Temp\ipykernel_13564\4041946048.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   max_features  =  trial.suggest_uniform("max_features", 0.01, 1.0)
# [I 2022-12-23 17:50:17,367] Trial 49 finished with value: 0.9335976214073339 and parameters: {'criterion': 'entropy', 'n_estimators': 816, 'max_depth': 19, 'max_features': 0.05546128085242047}. Best is trial 49 with value: 0.9335976214073339.

# %%
# To get the dictionary of parameter name and parameter values:
print("Return a dictionary of parameter name and parameter values:",study.best_params)

# To get the best observed value of the objective function:
print("Return the best observed value of the objective function:",study.best_value)

# To get the best trial:
print("Return the best trial:",study.best_trial)

# To get all trials:
# print("Return all the trials:", study.trials)
# Out:
# Return a dictionary of parameter name and parameter values: {'criterion': 'entropy', 'n_estimators': 816, 'max_depth': 19, 'max_features': 0.05546128085242047}
# Return the best observed value of the objective function: 0.9335976214073339
# Return the best trial: FrozenTrial(number=49, values=[0.9335976214073339], datetime_start=datetime.datetime(2022, 12, 23, 17, 50, 5, 478145), datetime_complete=datetime.datetime(2022, 12, 23, 17, 50, 17, 366867), params={'criterion': 'entropy', 'n_estimators': 816, 'max_depth': 19, 'max_features': 0.05546128085242047}, distributions={'criterion': CategoricalDistribution(choices=('gini', 'entropy')), 'n_estimators': IntDistribution(high=1000, log=False, low=10, step=1), 'max_depth': IntDistribution(high=20, log=False, low=3, step=1), 'max_features': FloatDistribution(high=1.0, log=False, low=0.01, step=None)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=49, state=TrialState.COMPLETE, value=None)

# %%
#importing all the plot functions
from optuna.visualization import plot_edf
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_slice

# %%
# Visualize the optimization history. See :func:`~optuna.visualization.plot_optimization_history` for the details.
plot_optimization_history(study)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File e:\Ineuron\self exploration\Hyperparameter\venv\lib\site-packages\optuna\visualization\_plotly_imports.py:7
#       6 with try_import() as _imports:  # NOQA
# ----> 7     import plotly  # NOQA
#       8     from plotly import __version__ as plotly_version
#
# ModuleNotFoundError: No module named 'plotly'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Visualize the optimization history. See :func:`~optuna.visualization.plot_optimization_history` for the details.
# ----> 2 plot_optimization_history(study)
#
# File e:\Ineuron\self exploration\Hyperparameter\venv\lib\site-packages\optuna\visualization\_optimization_history.py:167, in plot_optimization_history(study, target, target_name, error_bar)
#     117 def plot_optimization_history(
#     118     study: Union[Study, Sequence[Study]],
#     119     *,
#    (...)
#     122     error_bar: bool = False,
#     123 ) -> "go.Figure":
#     124     """Plot optimization history of all trials in a study.
#     125
#     126     Example:
#    (...)
#     164         A :class:`plotly.graph_objs.Figure` object.
#     165     """
# --> 167     _imports.check()
#     169     info_list = _get_optimization_history_info_list(study, target, target_name, error_bar)
#     170     return _get_optimization_history_plot(info_list, target_name)
#
# File e:\Ineuron\self exploration\Hyperparameter\venv\lib\site-packages\optuna\_imports.py:89, in _DeferredImportExceptionContextManager.check(self)
#      87 if self._deferred is not None:
#      88     exc_value, message = self._deferred
# ---> 89     raise ImportError(message) from exc_value
#
# ImportError: Tried to import 'plotly' but failed. Please make sure that the package is installed correctly to use this feature. Actual error: No module named 'plotly'.
